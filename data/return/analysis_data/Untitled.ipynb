# %%
import pandas as pd
import os
import numpy as np

# %%
data = list(os.listdir('/Users/ljhee/Desktop/4-1/DataMining/project/data/return/analysis_data'))

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data.remove('.DS_Store')
data.remove('.ipynb_checkpoints')
data.remove('Untitled.ipynb')

# %%
temp = []
for _data in data:
    df = pd.read_csv(_data,encoding = 'euc-kr')
    temp.append((_data,np.mean(df['return_num'])))

# %%
temp
# Out:
# [('건국대학교 (행정관)_return_data.csv', 1.2158675799086758),
#  ('dong_unif_return_data.csv', 2.8360730593607304),
#  ('dong_sample_return_data.csv', 1.4922374429223744),
#  ('gu_sample_return_data.csv', 2.4431506849315068),
#  ('건국대학교 정문 앞_return_data.csv', 2.1945205479452055),
#  ('화양 APT(횡단보도 옆)_return_data.csv', 4.929566210045662),
#  ('화양사거리_return_data.csv', 1.0616438356164384),
#  ('화양동 우체국_return_data.csv', 3.037785388127854),
#  ('어린이대공원역 3번출구 앞_return_data.csv', 3.7764840182648403),
#  ('건국대학교 과학관(이과대) 앞_return_data.csv', 2.2327625570776255),
#  ('건국대학교 학생회관_return_data.csv', 5.878310502283105),
#  ('광진 캠퍼스시티_return_data.csv', 3.881849315068493),
#  ('건대병원후문_return_data.csv', 7.404680365296803),
#  ('건국대학교 (입학정보관)_return_data.csv', 3.2554794520547947)]

# %%
sns.countplot(df['return_num'])
# Out:
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='return_num', ylabel='count'>

# %%
for _data in data:
    df = pd.read_csv(_data,encoding = 'euc-kr')
    sns.countplot(df['return_num'])
    plt.title(_data)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 4352 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 4453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 4523 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
ndf = pd.read_csv('건대병원후문_return_data.csv')

# %%
sns.countplot(ndf['return_num'])
# Out:
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='return_num', ylabel='count'>

# %%
ndf = pd.read_csv('건국대학교 학생회관_return_data.csv')
sns.countplot(ndf['return_num'])
# Out:
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='return_num', ylabel='count'>

# %%
ndf = pd.read_csv('화양 APT(횡단보도 옆)_return_data.csv')
sns.countplot(ndf['return_num'])
# Out:
# /Users/ljhee/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='return_num', ylabel='count'>

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
import xgboost as xgb

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("건국대학교 과학관(이과대) 앞_return_data.csv")

# %%
df.drop(['timestamp','spot_number'],axis=1,inplace=True)

# %%
df = df.sample(frac = 0.8)

# %%
X = df.drop('return_num',axis = 1); y  = df.return_num
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
model = XGBRegressor(max_depth=9,n_estimators=1000,)
model.fit(X_train,y_train)
pred = model.predict(X_test)
mean_squared_error(pred, y_test)
# Out:
# 5.609411996671191

# %%
from xgboost.sklearn import XGBClassifier, XGBRegressor

# %%
ndf = df
